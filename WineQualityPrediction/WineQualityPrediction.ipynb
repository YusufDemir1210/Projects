# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('WineQT.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
sns.regplot(data=df, x="residual sugar", y="quality")
# Out:
# <Axes: xlabel='residual sugar', ylabel='quality'>

# %%
plt.figure(figsize=(50,20))
plt.tight_layout()
sns.countplot(data=df, hue="quality", x="alcohol")
plt.show()

# %%
sns.pairplot(data=df)

# %%
y = df["quality"]
X = df.drop('quality',axis=1)

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xTrain,xTest,yTrain,yTest = train_test_split(X,y,test_size=0.31, random_state=42)

# %%
import sklearn as sk
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier()
forest.fit(xTrain,yTrain)
predictions = forest.predict(xTest)

# %%
predictions
# Out:
# array([5, 6, 5, 5, 5, 6, 5, 5, 5, 5, 7, 6, 6, 6, 5, 5, 6, 5, 5, 7, 6, 6,
#        5, 7, 5, 5, 7, 6, 5, 6, 5, 6, 7, 6, 5, 5, 6, 6, 6, 5, 7, 6, 6, 5,
#        5, 5, 6, 6, 5, 6, 7, 5, 6, 7, 6, 7, 6, 6, 6, 5, 5, 6, 6, 7, 6, 6,
#        6, 5, 5, 5, 8, 6, 5, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6, 5, 5, 6, 5, 5,
#        6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 7, 5, 6, 5, 5, 6, 7, 6, 7,
#        7, 5, 5, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 6, 5, 6, 5, 5,
#        6, 6, 7, 5, 5, 5, 5, 6, 7, 5, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 6, 5,
#        6, 5, 5, 5, 7, 6, 5, 6, 6, 6, 7, 5, 6, 6, 6, 5, 6, 5, 6, 5, 5, 5,
#        7, 5, 6, 5, 6, 5, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 7, 6, 6, 6, 5, 6,
#        7, 6, 6, 6, 5, 6, 7, 7, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 6, 5, 7, 5,
#        6, 5, 5, 6, 5, 6, 6, 6, 6, 5, 6, 7, 6, 5, 6, 7, 5, 6, 5, 5, 6, 5,
#        6, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 7, 5, 5, 5, 5, 6, 7, 6,
#        5, 5, 6, 6, 5, 6, 6, 7, 5, 6, 5, 6, 5, 6, 6, 5, 5, 6, 5, 5, 5, 7,
# ...

# %%
yTest
# Out:
# 158     5
# 1081    6
# 291     5
# 538     6
# 367     6
#        ..
# 614     5
# 65      5
# 409     6
# 557     6
# 1033    7
# Name: quality, Length: 355, dtype: int64

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(yTest, predictions)
# Out:
# 0.36901408450704226

# %%
np.sqrt(metrics.mean_squared_error(yTest, predictions))
# Out:
# 0.6650214441104592

# %%
sns.kdeplot(data=yTest)
sns.kdeplot(data=predictions)
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
metrics.confusion_matrix(yTest,predictions)
# Out:
# array([[  0,   0,   1,   0,   0,   0],
#        [  0,   0,   6,   3,   0,   0],
#        [  0,   0, 114,  32,   3,   0],
#        [  0,   0,  47,  96,   5,   1],
#        [  0,   0,   2,  15,  26,   0],
#        [  0,   0,   0,   3,   0,   1]], dtype=int64)

# %%
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         9
#            5       0.67      0.77      0.71       149
#            6       0.64      0.64      0.64       149
#            7       0.76      0.60      0.68        43
#            8       0.50      0.25      0.33         4
#
#     accuracy                           0.67       355
#    macro avg       0.43      0.38      0.39       355
# weighted avg       0.65      0.67      0.66       355
# D:\PycharmProjects\DataScience\venv\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
